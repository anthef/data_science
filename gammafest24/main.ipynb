# %%
import numpy as np
import os
import argparse
import cv2
import imutils

from matplotlib import pyplot as plt
from collections import Counter

# %% [markdown]
# ## Loading

# %%
def load_images_from_folder(folder):
    images = []
    dimensions = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        if os.path.isfile(img_path):
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            if img is not None:
                images.append(img)
                dimensions.append(img.shape[:2])  # Append the (height, width)
    return images, dimensions

# %%
folder = "Train"
images, dimensions = load_images_from_folder(folder)

# %% [markdown]
# ## Resizing

# %%
def analyze_image_dimensions(dimensions):
    heights = [dim[0] for dim in dimensions]
    widths = [dim[1] for dim in dimensions]

    average_height = np.mean(heights)
    average_width = np.mean(widths)
    median_height = np.median(heights)
    median_width = np.median(widths)

    height_freq = Counter(heights)
    width_freq = Counter(widths)

    most_common_heights = height_freq.most_common(3)
    most_common_widths = width_freq.most_common(3)

    return {
        "average_height": average_height,
        "average_width": average_width,
        "median_height": median_height,
        "median_width": median_width,
        "most_common_heights": most_common_heights,
        "most_common_widths": most_common_widths
    }

stats = analyze_image_dimensions(dimensions)

print("Image Dimension Statistics:")
print(f"Average Height: {stats['average_height']:.2f}")
print(f"Average Width: {stats['average_width']:.2f}")
print(f"Median Height: {stats['median_height']}")
print(f"Median Width: {stats['median_width']}")
print("Top 3 Most Common Heights:", stats['most_common_heights'])
print("Top 3 Most Common Widths:", stats['most_common_widths'])
# Out:
# Image Dimension Statistics:
# Average Height: 859.32
# Average Width: 747.52
# Median Height: 944.5
# Median Width: 810.0
# Top 3 Most Common Heights: [(961, 14), (962, 13), (965, 9)]
# Top 3 Most Common Widths: [(813, 22), (819, 14), (816, 11)]

# %%
def resize_images(images, target_size=(961, 813)):
    resized_images = []
    for i in range(len(images)):
        image = images[i]
        original_size = image.shape[:2]
        if original_size[0] < target_size[0] or original_size[1] < target_size[1]:
            interpolation = cv2.INTER_CUBIC
        else:
            interpolation = cv2.INTER_LINEAR

        resized_image = cv2.resize(image, (target_size[1], target_size[0]), interpolation=interpolation)
        # cv2.imwrite(f"train_grayscale_resized/{i}.jpg", resized_image)
        resized_images.append(resized_image)
    return resized_images

resized_train = resize_images(images)

# %% [markdown]
# ## Color

# %%
def extract_blue_channel(images):
    for i in range(len(images)):
        image = images[i]
        (B, G, R) = cv2.split(image)
        cv2.imwrite(f"train_blue_channel/{i}.jpg", B)

extract_blue_channel(images)

# %% [markdown]
# ## Enhancing Image (Applying CLAHE)

# %%
def enhance_text_image(images):
    for i in range(len(images)):
        image = images[i]
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
        enhanced_image = clahe.apply(image)
        cv2.imwrite(f"train_enhanced2/{i}.jpg", enhanced_image)

enhance_text_image(resized_train)

# %% [markdown]
# # Image Registration

# %%
import cv2 
import numpy as np 
import os

directory = "train_enhanced/train_enhanced"

file_list = os.listdir(directory)

orb_detector = cv2.ORB_create(5000) 

for i in range(len(file_list)):
    if i != 1: 
        img1_color = cv2.imread(os.path.join(directory, file_list[0]))  # Image to be aligned. 
        img2_color = cv2.imread(os.path.join(directory, file_list[i]))  # Reference image. 

        img1 = img1_color
        img2 = img2_color
        
        height, width = img2.shape[:2]

        kp1, d1 = orb_detector.detectAndCompute(img1, None) 
        kp2, d2 = orb_detector.detectAndCompute(img2, None) 

        matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True) 

        matches_tuple = matcher.match(d1, d2) 
        matches = list(matches_tuple)

        matches.sort(key=lambda x: x.distance) 

        matches = matches[:int(len(matches)*0.9)] 
        no_of_matches = len(matches) 

        p1 = np.zeros((no_of_matches, 2)) 
        p2 = np.zeros((no_of_matches, 2)) 

        for j in range(len(matches)): 
            p1[j, :] = kp1[matches[j].queryIdx].pt 
            p2[j, :] = kp2[matches[j].trainIdx].pt 

        homography, mask = cv2.findHomography(p1, p2, cv2.RANSAC) 
        transformed_img = cv2.warpPerspective(img1_color, homography, (width, height)) 

        cv2.imwrite(os.path.join(directory, file_list[i]), transformed_img)
    else:
        continue

# %% [markdown]
# # Rotation

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
from PIL import Image
import os

dir_path = 'train_enhanced/train_enhanced'


jpg_files = [f for f in os.listdir(dir_path) if f.endswith('.jpg')]

for file in jpg_files:
    img = Image.open(os.path.join(dir_path, file))
    width, height = img.size
    num_channels = len(img.getbands())
    print(f'Gambar {file}: Dimensi = {width} x {height}, Saluran Warna = {num_channels}')
# Out:
# Gambar 0.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 1.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 10.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 100.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 101.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 102.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 103.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 104.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 105.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 106.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 107.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 108.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 109.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 11.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 110.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 111.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 112.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 113.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 114.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 115.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 116.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 117.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 118.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 119.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 12.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 120.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 121.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 122.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 123.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 124.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 125.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 126.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 127.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 128.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 129.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 13.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 130.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 131.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 132.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 133.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 134.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 135.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 136.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 137.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 138.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 139.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 14.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 140.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 141.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 142.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 143.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 144.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 145.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 146.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 147.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 148.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 149.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 15.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 150.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 151.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 152.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 153.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 154.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 155.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 156.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 157.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 158.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 159.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 16.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 160.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 161.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 162.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 163.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 164.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 165.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 166.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 167.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 168.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 169.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 17.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 170.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 171.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 172.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 173.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 174.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 175.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 176.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 177.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 178.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 179.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 18.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 180.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 181.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 182.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 183.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 184.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 185.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 186.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 187.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 188.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 189.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 19.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 190.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 191.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 192.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 193.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 194.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 195.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 196.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 197.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 198.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 199.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 2.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 20.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 200.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 201.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 202.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 203.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 204.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 205.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 206.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 207.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 208.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 209.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 21.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 210.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 211.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 212.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 213.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 214.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 215.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 216.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 217.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 218.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 219.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 22.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 220.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 221.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 222.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 223.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 224.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 225.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 226.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 227.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 228.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 229.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 23.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 230.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 231.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 232.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 233.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 234.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 235.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 236.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 237.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 238.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 239.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 24.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 240.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 241.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 242.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 243.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 244.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 245.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 246.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 247.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 248.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 249.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 25.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 250.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 251.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 252.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 253.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 254.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 255.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 256.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 257.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 258.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 259.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 26.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 260.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 261.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 262.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 263.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 264.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 265.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 266.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 267.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 268.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 269.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 27.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 270.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 271.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 272.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 273.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 274.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 275.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 276.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 277.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 278.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 279.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 28.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 280.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 281.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 282.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 283.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 284.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 285.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 286.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 287.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 288.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 289.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 29.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 290.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 291.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 292.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 293.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 294.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 295.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 296.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 297.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 298.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 299.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 3.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 30.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 300.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 301.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 302.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 303.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 304.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 305.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 306.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 307.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 308.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 309.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 31.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 310.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 311.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 312.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 313.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 314.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 315.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 316.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 317.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 318.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 319.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 32.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 320.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 321.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 322.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 323.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 324.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 325.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 326.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 327.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 328.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 329.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 33.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 330.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 331.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 332.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 333.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 334.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 335.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 336.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 337.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 338.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 339.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 34.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 340.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 341.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 342.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 343.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 344.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 345.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 346.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 347.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 348.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 349.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 35.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 350.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 351.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 352.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 353.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 354.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 355.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 356.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 357.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 358.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 359.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 36.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 360.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 361.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 362.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 363.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 364.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 365.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 366.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 367.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 368.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 369.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 37.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 370.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 371.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 372.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 373.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 374.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 375.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 376.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 377.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 378.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 379.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 38.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 380.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 381.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 382.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 383.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 384.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 385.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 386.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 387.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 388.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 389.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 39.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 390.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 391.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 392.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 393.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 394.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 395.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 396.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 397.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 398.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 399.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 4.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 40.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 400.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 401.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 402.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 403.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 404.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 405.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 406.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 407.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 408.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 409.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 41.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 410.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 411.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 412.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 413.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 414.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 415.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 416.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 417.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 418.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 419.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 42.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 420.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 421.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 422.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 423.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 424.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 425.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 426.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 427.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 428.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 429.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 43.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 430.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 431.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 432.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 433.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 434.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 435.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 436.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 437.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 438.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 439.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 44.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 440.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 441.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 442.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 443.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 444.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 445.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 446.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 447.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 448.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 449.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 45.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 450.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 451.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 452.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 453.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 454.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 455.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 456.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 457.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 458.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 459.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 46.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 460.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 461.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 462.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 463.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 464.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 465.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 466.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 467.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 468.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 469.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 47.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 470.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 471.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 472.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 473.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 474.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 475.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 476.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 477.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 478.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 479.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 48.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 480.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 481.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 482.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 483.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 484.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 485.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 486.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 487.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 488.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 489.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 49.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 490.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 491.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 492.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 493.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 494.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 495.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 496.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 497.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 498.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 499.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 5.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 50.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 51.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 52.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 53.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 54.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 55.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 56.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 57.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 58.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 59.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 6.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 60.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 61.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 62.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 63.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 64.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 65.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 66.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 67.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 68.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 69.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 7.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 70.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 71.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 72.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 73.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 74.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 75.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 76.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 77.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 78.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 79.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 8.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 80.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 81.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 82.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 83.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 84.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 85.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 86.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 87.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 88.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 89.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 9.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 90.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 91.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 92.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 93.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 94.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 95.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 96.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 97.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 98.jpg: Dimensi = 813 x 961, Saluran Warna = 1
# Gambar 99.jpg: Dimensi = 813 x 961, Saluran Warna = 1

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(813, 961, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(4, activation='softmax'))  

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# c:\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


datagen = ImageDataGenerator(rescale=1./255)

# Menyiapkan data train
train_generator = datagen.flow_from_directory(
    'train_enhanced',  # direktori data latih
    target_size=(813, 961),  # mengubah resolusi seluruh gambar menjadi 813x961 piksel
    color_mode='grayscale',
    batch_size=32,
    class_mode='categorical')
# Out:
# Found 500 images belonging to 1 classes.

# %%
def correct_image_orientation(img):
    # Gunakan model Anda untuk memprediksi orientasi gambar
    predicted_rotation = 180
    
    if predicted_rotation == 180:
        img = cv2.rotate(img, cv2.ROTATE_180)
    return img

# %%
def load_and_correct_images_from_folder(folder):
    images = []
    dimensions = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        if os.path.isfile(img_path):
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            if img is not None:
                img = correct_image_orientation(img)
                images.append(img)
                dimensions.append(img.shape[:2])  # Append the (height, width)
    return images, dimensions

# %%
# import cv2
# import os
# import pytesseract
# from pytesseract import Output
# from scipy import ndimage

# pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# def get_image_resolution(image_path):
#     img = cv2.imread(image_path)
#     height, width, _ = img.shape
#     return width, height

# def rotate_image_if_needed(image_path):
#     try:
#         # Membaca gambar
#         img = cv2.imread(image_path, 0)

#         # Mendeteksi teks dalam gambar
#         d = pytesseract.image_to_osd(img, output_type=Output.DICT)

#         # Mendapatkan orientasi teks
#         rotate_angle = d['rotate']

#         # Jika teks terbaca terbalik, putar gambar 180 derajat
#         if rotate_angle == 180:
#             rotated_img = ndimage.rotate(img, 180)
#             cv2.imwrite(image_path, rotated_img)
#     except pytesseract.TesseractError as e:
#         print(f"Error processing {image_path}: {e}")
#         pass

# # Mendapatkan daftar semua file gambar dalam direktori
# image_files = os.listdir('train_enhanced/train_enhanced')

# # Memproses setiap gambar
# for image_file in image_files:
#     image_path = os.path.join('train_enhanced/train_enhanced', image_file)
    
#     # Mendapatkan resolusi gambar
#     width, height = get_image_resolution(image_path)
    
#     # Melakukan pengecekan resolusi
#     if width < 813 or height < 961:  # Ubah nilai threshold sesuai kebutuhan Anda
#         print(f"Ignoring {image_file} due to low resolution.")
#         continue
    
#     rotate_image_if_needed(image_path)
# Out:
# Error processing train_enhanced/train_enhanced\138.jpg: (1, 'Estimating resolution as 307 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\173.jpg: (1, 'Estimating resolution as 652 Too few characters. Skipping this page Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\177.jpg: (1, 'Estimating resolution as 645 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\230.jpg: (1, 'Estimating resolution as 328 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\277.jpg: (1, 'Estimating resolution as 408 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\286.jpg: (1, 'Estimating resolution as 444 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\340.jpg: (1, 'Estimating resolution as 463 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\366.jpg: (1, 'Estimating resolution as 359 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\38.jpg: (1, 'Estimating resolution as 280 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\407.jpg: (1, 'Estimating resolution as 296 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\413.jpg: (1, 'Estimating resolution as 389 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\415.jpg: (1, 'Estimating resolution as 533 Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')
# Error processing train_enhanced/train_enhanced\54.jpg: (1, 'Estimating resolution as 572 Too few characters. Skipping this page Warning. Invalid resolution 0 dpi. Using 70 instead. Too few characters. Skipping this page Error during processing.')

# %%
import cv2
import pytesseract
from pytesseract import Output

# Set the path to the tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Function to rotate image
def rotate_image(image):
    return cv2.rotate(image, cv2.ROTATE_180)


for i in range(500):
    image_path = f'train_enhanced/train_enhanced/{i}.jpg'  # Update with your path and image format
    image = cv2.imread(image_path)

    # Check if the image is None
    if image is None:
        print(f"No image found at {image_path}")
        continue

    # Get the dimensions of the image
    height, width = image.shape[:2]

    # Perform OCR on the image to get text bounding boxes
    d = pytesseract.image_to_data(image, output_type=Output.DICT)
    n_boxes = len(d['text'])

    for i in range(n_boxes):
        if int(d['conf'][i]) > 60:
            (x, y, w, h) = (d['left'][i], d['top'][i], d['width'][i], d['height'][i])

            # Check if the text is closer to the top right edge
            if x > width/2 and y < height/2:
                # Rotate the image
                image = rotate_image(image)
                break

    # Overwrite the original image
    cv2.imwrite(image_path, image)
# Out:
# No image found at train_enhanced/train_enhanced/500.jpg

# %%
def crop_image(image, no):
    height = 320
    width = 230
    
    x = 813-230
    y = 30
    cropped_image_1 = image[y:y+height, x:x+width]
    cv2.imwrite(f'working/kanan/{no}_kanan_1.jpg', cropped_image_1) 
    
    x = 813-230
    y = 330
    cropped_image_2 = image[y:y+height, x:x+width]
    cv2.imwrite(f'working/kanan/{no}_kanan_2.jpg', cropped_image_2) 
    
    x = 813-230
    y = 961-320
    cropped_image_3 = image[y:y+height, x:x+width]
    cv2.imwrite(f'working/kanan/{no}_kanan_3.jpg', cropped_image_3)
